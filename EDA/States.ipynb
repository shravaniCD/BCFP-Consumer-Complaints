# %% [markdown]
# ## Statewise ZIPCODE dataset

# %%
import pandas as pd

# %%
#data=pd.read_csv('../data/Consumer_Complaints.csv',nrows = 2000)
data=pd.read_csv('../data/state.csv',sep='\t')

# %%
data
# Out:
#    State     start  end
# 0   [AL]   35801  35816
# 1   [AK]   99501  99524
# 2   [AZ]   85001  85055
# 3   [AR]   72201  72217
# 4   [CA]   94203  94209
# 5   [CA]   90001  90089
# 6   [CA]   90209  90213
# 7   [CO]   80201  80239
# 8   [CT]   06101  06112
# 9   [DE]   19901  19905
# 10  [DC]   20001  20020
# 11  [FL]   32501  32509
# 12  [FL]  33124  33190
# 13  [FL]   32801  32837
# 14  [GA]   30301  30381
# 15  [HI]   96801  96830
# 16  [ID]          83254
# 17  [IL]   60601  60641
# 18  [IL]   62701  62709
# 19  [IN]   46201  46209
# 20  [IA]   52801  52809
# 21  [IA]   50301  50323
# 22  [KS]   67201  67221
# 23  [KY]   41701  41702
# 24  [LA]   70112  70119
# 25  [ME]   04032  04034
# 26  [MD]   21201  21237
# 27  [MA]   02101  02137
# 28  [MI]          49036
# 29  [MI]   49734  49735
# 30  [MN]   55801  55808
# 31  [MS]   39530  39535
# 32  [MO]   63101  63141
# 33  [MT]          59044
# 34  [NE]   68901  68902
# 35  [NV]   89501  89513
# 36  [NH]          03217
# ...

# %%
data=data.drop('Region',axis=1)

# %%
data.State=data.State.str.findall(r'\((.+?)\)')

# %%
data.head()
# Out:
#   State    start  end
# 0  [AL]  35801  35816
# 1  [AK]  99501  99524
# 2  [AZ]  85001  85055
# 3  [AR]  72201  72217
# 4  [CA]  94203  94209

# %%
data.State[data['start  end'].str.contains('604')]
# Out:
# Series([], Name: State, dtype: object)

# %%
data.columns
# Out:
# Index(['State', 'start  end'], dtype='object')
